# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %%
df = pd.read_csv('corrected_dataset.csv').drop(columns='Unnamed: 0')

# %%
df
# Out:
#           bodyType       brand        color  engineDisplacement  enginePower  \
# 0      внедорожник        AUDI        синий                 3.0        249.0
# 1          хэтчбек        AUDI        белый                 1.4        122.0
# 2             купе        AUDI        белый                 1.8        170.0
# 3        универсал        AUDI       чёрный                 2.0        140.0
# 4            седан        AUDI   коричневый                 3.1        255.0
# ...            ...         ...          ...                 ...          ...
# 31343        седан  VOLKSWAGEN      бежевый                 1.4        125.0
# 31344        седан  VOLKSWAGEN  серебристый                 1.6        110.0
# 31345    универсал  VOLKSWAGEN        синий                 2.0        140.0
# 31346      минивэн  VOLKSWAGEN        белый                 1.4        150.0
# 31347    универсал  VOLKSWAGEN        серый                 1.4        150.0
#
#       engine_name fuelType    km_age             metro  modelDate  \
# 0              AT   дизель       0.0  ['Авиамоторная']       2018
# 1             AMT   бензин  138000.0               NaN       2010
# 2             CVT   бензин   84570.0               NaN       2011
# 3             CVT   дизель  185000.0               NaN       2004
# 4              AT   бензин  142306.0        ['Аннино']       2004
# ...           ...      ...       ...               ...        ...
# 31343         AMT   бензин   63000.0               NaN       2014
# 31344          AT   бензин   33000.0               NaN       2014
# 31345          MT   дизель  210000.0               NaN       2005
# 31346         AMT   бензин   34000.0               NaN       2015
# 31347         AMT   бензин   61000.0               NaN       2014
#
#                                   name  numberOfDoors    price  \
# 0                    Audi Q8  I 45 TDI              5  6590000
# 1                       Audi A1 I (8X)              3   580000
# 2            Audi A5 I (8T) Рестайлинг              2   915000
# 3                 Audi A4  III (B7) 8V              5   445000
# 4                     Audi A6 III (C6)              4   499000
# ...                                ...            ...      ...
# 31343     Volkswagen Polo V Рестайлинг              4   680000
# 31344     Volkswagen Polo V Рестайлинг              4   680000
# 31345             Volkswagen Passat B6              5   499000
# 31346  Volkswagen Sharan II Рестайлинг              5   888000
# 31347             Volkswagen Passat B8              5  1050000
#
#        productionDate           vehicleConfiguration vehicleTransmission  \
# 0                2020  ALLROAD_5_DOORS AUTOMATIC 3.0      автоматическая
# 1                2012    HATCHBACK_3_DOORS ROBOT 1.4    роботизированная
# 2                2013             COUPE VARIATOR 1.8            вариатор
# 3                2007     WAGON_5_DOORS VARIATOR 2.0            вариатор
# 4                2006            SEDAN AUTOMATIC 3.1      автоматическая
# ...               ...                            ...                 ...
# 31343            2017                SEDAN ROBOT 1.4    роботизированная
# 31344            2016            SEDAN AUTOMATIC 1.6      автоматическая
# 31345            2010   WAGON_5_DOORS MECHANICAL 2.0        механическая
# 31346            2015              MINIVAN ROBOT 1.4    роботизированная
# 31347            2015        WAGON_5_DOORS ROBOT 1.4    роботизированная
#
#               city
# 0           moskva
# 1           moskva
# 2           moskva
# 3           moskva
# 4           moskva
# ...            ...
# 31343  vladivostok
# 31344  vladivostok
# 31345  vladivostok
# 31346  vladivostok
# 31347  vladivostok
#
# [31348 rows x 17 columns]

# %% [markdown]
# ## Launch learning steps

# %%
main_df = df.drop(columns=['metro', 'vehicleConfiguration'])
main_df
# Out:
#           bodyType       brand        color  engineDisplacement  enginePower  \
# 0      внедорожник        AUDI        синий                 3.0        249.0
# 1          хэтчбек        AUDI        белый                 1.4        122.0
# 2             купе        AUDI        белый                 1.8        170.0
# 3        универсал        AUDI       чёрный                 2.0        140.0
# 4            седан        AUDI   коричневый                 3.1        255.0
# ...            ...         ...          ...                 ...          ...
# 31343        седан  VOLKSWAGEN      бежевый                 1.4        125.0
# 31344        седан  VOLKSWAGEN  серебристый                 1.6        110.0
# 31345    универсал  VOLKSWAGEN        синий                 2.0        140.0
# 31346      минивэн  VOLKSWAGEN        белый                 1.4        150.0
# 31347    универсал  VOLKSWAGEN        серый                 1.4        150.0
#
#       engine_name fuelType    km_age  modelDate  \
# 0              AT   дизель       0.0       2018
# 1             AMT   бензин  138000.0       2010
# 2             CVT   бензин   84570.0       2011
# 3             CVT   дизель  185000.0       2004
# 4              AT   бензин  142306.0       2004
# ...           ...      ...       ...        ...
# 31343         AMT   бензин   63000.0       2014
# 31344          AT   бензин   33000.0       2014
# 31345          MT   дизель  210000.0       2005
# 31346         AMT   бензин   34000.0       2015
# 31347         AMT   бензин   61000.0       2014
#
#                                   name  numberOfDoors    price  \
# 0                    Audi Q8  I 45 TDI              5  6590000
# 1                       Audi A1 I (8X)              3   580000
# 2            Audi A5 I (8T) Рестайлинг              2   915000
# 3                 Audi A4  III (B7) 8V              5   445000
# 4                     Audi A6 III (C6)              4   499000
# ...                                ...            ...      ...
# 31343     Volkswagen Polo V Рестайлинг              4   680000
# 31344     Volkswagen Polo V Рестайлинг              4   680000
# 31345             Volkswagen Passat B6              5   499000
# 31346  Volkswagen Sharan II Рестайлинг              5   888000
# 31347             Volkswagen Passat B8              5  1050000
#
#        productionDate vehicleTransmission         city
# 0                2020      автоматическая       moskva
# 1                2012    роботизированная       moskva
# 2                2013            вариатор       moskva
# 3                2007            вариатор       moskva
# 4                2006      автоматическая       moskva
# ...               ...                 ...          ...
# 31343            2017    роботизированная  vladivostok
# 31344            2016      автоматическая  vladivostok
# 31345            2010        механическая  vladivostok
# 31346            2015    роботизированная  vladivostok
# 31347            2015    роботизированная  vladivostok
#
# [31348 rows x 15 columns]
